# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('00-puppy-Copy1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
imgWrong = cv2.imread('wrongpath00-puppy.jpg')

# %%
type(imgWrong)
# Out:
# NoneType

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB ---> R G B (Red Green Blue)
# OPENCV ---> Blue Green Red

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('00-puppy-Copy1.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(400,300))

# %%
plt.imshow(new_img)

# %%
w_ratio = 5
h_ratio = 5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,-1)

# %%
plt.imshow(new_img)

# %%
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
