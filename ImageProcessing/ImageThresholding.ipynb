# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("rainbow.jpg")

# %%
plt.imshow(img)

# %%
# Adding the 0 flag to read it in black and white
img = cv2.imread("rainbow.jpg",0)

# %%
plt.imshow(img,cmap='gray')

# %%
# Binary Threshold
# if src(x,y) > thresh
#   dst(x,y) = maxValue
# else
#   dst(x,y) = 0
ret, thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %%
# Inverse Binary Threshold
# if src(x,y) > thresh
#   dst(x,y) = 0
# else
#   dst(x,y) = maxValue
    
ret, thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh2, cmap='gray')

# %%
# Truncate Threshold
# if src(x,y) > thresh
#   dst(x,y) = thresh
# else
#   dst(x,y) = src(x,y)


ret, thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)

plt.imshow(thresh3,cmap='gray')

# %%
plt.imshow(img,cmap='gray')

# %%
# Threshold to Zero
# if src(x,y) > thresh
#   dst(x,y) = src(x,y)
# else
#   dst(x,y) = 0

ret, thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')

# %%
# Inverted Threshold to Zero
# if src(x,y) > thresh
#   dst(x,y) = 0
# else
#   dst(x,y) = src(x,y)

ret, thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
plt.imshow(thresh5,cmap='gray')

# %%
img = cv2.imread("crossword.jpg",0)

# %%
def show_pic(img):
    fig = plt.figure(figsize=(16,23))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
show_pic(img)

# %%
ret, th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
show_pic(th1)

# %%
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,13,13)
show_pic(th2)

# %%
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,14)
show_pic(th3)
